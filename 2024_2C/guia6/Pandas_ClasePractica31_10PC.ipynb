# %% [markdown]
# # [Ejercicios Guia Pandas](https://pensamientocomputacional.dev.ar/guia.html#pandas)

# %% [markdown]
# 6.3.3.2 [Atributos y descripción de un Dataframe](https://https://pensamientocomputacional.dev.ar/unidad_6.html#atributos-y-descripci%C3%B3n-de-un-dataframe)

# %% [markdown]
# | Método o atributo   | Descripción                                         |
# |---------------------|-----------------------------------------------------|
# | `.info()`           | Resume la información del DataFrame                 |
# | `.shape`            | Devuelve una tupla con el número de filas y columnas|
# | `.size`             | Número de elementos, aunque también puede usarse `len` |
# | `.columns`          | Lista con los nombres de las columnas               |
# | `.index`            | Lista con los nombres de las filas                  |
# | `.dtypes`           | Serie con los tipos de datos de las columnas        |
# | `.head()`           | Muestra las primeras filas                          |
# | `.tail()`           | Muestra las últimas filas                           |
# | `.describe()`       | Brinda métricas de las columnas numéricas

# %% [markdown]
# | Operaciones | Función   | Descripción                                         |
# |-------------|-----------|-----------------------------------------------------|
# | Máximo      | `max()`   | Valor máximo del array o del eje indicado           |
# | Mínimo      | `min()`   | Valor mínimo del array o del eje indicado           |
# | Suma        | `sum()`   | Suma de todos los elementos o del eje indicado      |
# | Promedio    | `mean()`  | Promedio de todos los elementos o del eje indicado  |

# %% [markdown]
# `!! Muchas veces no vamos a querer modificar el dataframe original, pero sin manipularlo. En ese caso, podemos hacer una copia del dataframe original, de esta forma: df_copy = df.copy()`

# %% [markdown]
# 6.3.3.9 [Ordenando, Contando y Agrupando](https://pensamientocomputacional.dev.ar/unidad_6.html#ordenando-contando-y-agrupando)

# %% [markdown]
# | Método                    | Descripción                                                                                                                      |
# |---------------------------|----------------------------------------------------------------------------------------------------------------------------------|
# | `sort_values(by, ascending)` | Ordena el DataFrame considerando los valores de la o las columnas determinadas y devuelve un DataFrame nuevo (no modifica el original) |
# | `value_counts()`          | Indica los valores únicos de una determinada columna y el número de veces que aparece en ella                                   |
# | `groupby().func()`        | Agrupa las filas según ciertos valores de columnas. Requiere que apliquemos una función luego para que ‘agrupe’ los datos       |

# %% [markdown]
# 6.3.3.5 [Modificar un Dataframe](https://pensamientocomputacional.dev.ar/unidad_6.html#modificar-un-dataframe)

# %% [markdown]
# | Método                  | Descripción                                                                                   |
# |-------------------------|-----------------------------------------------------------------------------------------------|
# | `rename()`              | Renombra las columnas                                                                        |
# | `insert()`              | Agrega columnas                                                                              |
# | `drop()`                | Elimina columnas y filas                                                                     |
# | `loc[fila]`             | Agrega una fila en un índice dado                                                            |
# | `loc[fila, columna]`    | Modifica un valor particular dado un índice y una columna                                    |
# | `map()`                 | Busca un valor dado en una columna y lo reemplaza                                            |
# | `replace()`             | Reemplaza un valor dado en una columna                                                       |

# %% [markdown]
# ---

# %%
import pandas as pd
data = {
    'nombre': ['Violeta', 'Carla', 'Manuela', 'Lucia', 'Emilia', 'Mariana', 'Aldo'],
    'apellido': ['Perez', 'Guanca', 'Gomez', 'Capon', 'Duzac', 'Szischik', 'Rastrelli'],
    'dni': [42000000, 42001001, 42002002, 37010020, 40001002, 38090080, 38111222],
    'año_nac': [1997, 1998, 1998, 1993, 2003, 1993, 1994],
    'mail': ['vp@fi.uba.ar', 'cg@fi.uba.ar', None, None, None, 'ms@fi.uba.ar', 'ar@fi.uba.ar'],
    'carrera': ['Informática', 'Mecánica', 'Química', 'Informática', 'Informática', 'Electrónica', 'Informática']
}

df = pd.DataFrame(data)
df
# Out:
#     nombre   apellido       dni  año_nac          mail      carrera
# 0  Violeta      Perez  42000000     1997  vp@fi.uba.ar  Informática
# 1    Carla     Guanca  42001001     1998  cg@fi.uba.ar     Mecánica
# 2  Manuela      Gomez  42002002     1998          None      Química
# 3    Lucia      Capon  37010020     1993          None  Informática
# 4   Emilia      Duzac  40001002     2003          None  Informática
# 5  Mariana   Szischik  38090080     1993  ms@fi.uba.ar  Electrónica
# 6     Aldo  Rastrelli  38111222     1994  ar@fi.uba.ar  Informática

# %% [markdown]
# 1. Mostrar el resumen de la información del DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   nombre    7 non-null      object
#  1   apellido  7 non-null      object
#  2   dni       7 non-null      int64
#  3   año_nac   7 non-null      int64
#  4   mail      4 non-null      object
#  5   carrera   7 non-null      object
# dtypes: int64(2), object(4)
# memory usage: 464.0+ bytes

# %% [markdown]
# 6. Agregar la nueva columna al DataFrame con la información de la edad de los estudiantes para el año actual y mostrar el DataFrame resultante

# %%
edades = 2024 - df["año_nac"]

df["edades"] = edades

# Alternativa
#df.insert(3,"edades",edades)

df
# Out:
#     nombre   apellido       dni  edades  año_nac          mail      carrera
# 0  Violeta      Perez  42000000      27     1997  vp@fi.uba.ar  Informática
# 1    Carla     Guanca  42001001      26     1998  cg@fi.uba.ar     Mecánica
# 2  Manuela      Gomez  42002002      26     1998          None      Química
# 3    Lucia      Capon  37010020      31     1993          None  Informática
# 4   Emilia      Duzac  40001002      21     2003          None  Informática
# 5  Mariana   Szischik  38090080      31     1993  ms@fi.uba.ar  Electrónica
# 6     Aldo  Rastrelli  38111222      30     1994  ar@fi.uba.ar  Informática

# %% [markdown]
# 8. Para los estudiantes que tienen edad mayor a 25, mostrar el promedio de edad.

# %%
df[edades > 25]["edades"].mean()
# Out:
# 28.5

# %% [markdown]
# 9. Mostrar a la persona que es más joven.

# %%
df.sort_values(by = ["edades", "dni"],ascending = [True, False], inplace = True)
df.head(1)
# Out:
#    nombre apellido       dni  edades  año_nac  mail      carrera
# 4  Emilia    Duzac  40001002      21     2003  None  Informática

# %% [markdown]
# 12. Mostrar sólo los estudiantes que estudian Informática.

# %%
df[df["carrera"] == "Informática"]
# Out:
#     nombre   apellido       dni  edades  año_nac          mail      carrera
# 4   Emilia      Duzac  40001002      21     2003          None  Informática
# 0  Violeta      Perez  42000000      27     1997  vp@fi.uba.ar  Informática
# 6     Aldo  Rastrelli  38111222      30     1994  ar@fi.uba.ar  Informática
# 3    Lucia      Capon  37010020      31     1993          None  Informática

# %% [markdown]
# 14. Reemplazar **Informática** por **Informática**  **o Sistemas**  en la columna “carrera”.

# %%
df["carrera"] = df["carrera"].replace("Informática" , "Info o sistemas")
df
# Out:
#     nombre   apellido       dni  edades  año_nac          mail  \
# 4   Emilia      Duzac  40001002      21     2003          None
# 2  Manuela      Gomez  42002002      26     1998          None
# 1    Carla     Guanca  42001001      26     1998  cg@fi.uba.ar
# 0  Violeta      Perez  42000000      27     1997  vp@fi.uba.ar
# 6     Aldo  Rastrelli  38111222      30     1994  ar@fi.uba.ar
# 5  Mariana   Szischik  38090080      31     1993  ms@fi.uba.ar
# 3    Lucia      Capon  37010020      31     1993          None
#
#            carrera
# 4  Info o sistemas
# 2          Química
# 1         Mecánica
# 0  Info o sistemas
# 6  Info o sistemas
# 5      Electrónica
# 3  Info o sistemas

# %% [markdown]
# 17. Para la primer estudiante, cambiar su carrera a “Electrónica”.

# %%
# Por indices
df.iloc[0,6] = "Electronica"

# Por etiquetas (No muy util en este caso)
#df.loc[4,"carrera"] = "Electronica"

df
# Out:
#     nombre   apellido       dni  edades  año_nac          mail  \
# 4   Emilia      Duzac  40001002      21     2003   Electronica
# 2  Manuela      Gomez  42002002      26     1998          None
# 1    Carla     Guanca  42001001      26     1998  cg@fi.uba.ar
# 0  Violeta      Perez  42000000      27     1997  vp@fi.uba.ar
# 6     Aldo  Rastrelli  38111222      30     1994  ar@fi.uba.ar
# 5  Mariana   Szischik  38090080      31     1993  ms@fi.uba.ar
# 3    Lucia      Capon  37010020      31     1993          None
#
#            carrera
# 4      Electronica
# 2          Química
# 1         Mecánica
# 0      Electronica
# 6  Info o sistemas
# 5      Electrónica
# 3  Info o sistemas

# %% [markdown]
# 19. Agregar una nueva columna ‘tiene_mail’, con un valor booleano que indique si la estudiante tiene mail en el sistema.

# %%
df["tiene_mail"] = df["mail"].notnull()
df
# Out:
#     nombre   apellido       dni  edades  año_nac          mail  \
# 4   Emilia      Duzac  40001002      21     2003   Electronica
# 2  Manuela      Gomez  42002002      26     1998          None
# 1    Carla     Guanca  42001001      26     1998  cg@fi.uba.ar
# 0  Violeta      Perez  42000000      27     1997  vp@fi.uba.ar
# 6     Aldo  Rastrelli  38111222      30     1994  ar@fi.uba.ar
# 5  Mariana   Szischik  38090080      31     1993  ms@fi.uba.ar
# 3    Lucia      Capon  37010020      31     1993          None
#
#            carrera  tiene_mail
# 4      Electronica        True
# 2          Química       False
# 1         Mecánica        True
# 0      Electronica        True
# 6  Info o sistemas        True
# 5      Electrónica        True
# 3  Info o sistemas       False

# %% [markdown]
# 21. Ordenar el dataFrame por carrera y apellido, en ese orden.

# %%
df.sort_values(by = ["carrera", "apellido"])
# Out:
#     nombre   apellido       dni  edades  año_nac          mail  \
# 4   Emilia      Duzac  40001002      21     2003   Electronica
# 0  Violeta      Perez  42000000      27     1997  vp@fi.uba.ar
# 5  Mariana   Szischik  38090080      31     1993  ms@fi.uba.ar
# 3    Lucia      Capon  37010020      31     1993          None
# 6     Aldo  Rastrelli  38111222      30     1994  ar@fi.uba.ar
# 1    Carla     Guanca  42001001      26     1998  cg@fi.uba.ar
# 2  Manuela      Gomez  42002002      26     1998          None
#
#            carrera  tiene_mail
# 4      Electronica        True
# 0      Electronica        True
# 5      Electrónica        True
# 3  Info o sistemas       False
# 6  Info o sistemas        True
# 1         Mecánica        True
# 2          Química       False

# %% [markdown]
# 22. Ordenar el dataFrame por carrera y edad. Carrera por forma ascendente, edad por forma descendente.

# %%
df.sort_values(by = ["carrera", "edades"], ascending = [True,False])
# Out:
#     nombre   apellido       dni  edades  año_nac          mail  \
# 0  Violeta      Perez  42000000      27     1997  vp@fi.uba.ar
# 4   Emilia      Duzac  40001002      21     2003   Electronica
# 5  Mariana   Szischik  38090080      31     1993  ms@fi.uba.ar
# 3    Lucia      Capon  37010020      31     1993          None
# 6     Aldo  Rastrelli  38111222      30     1994  ar@fi.uba.ar
# 1    Carla     Guanca  42001001      26     1998  cg@fi.uba.ar
# 2  Manuela      Gomez  42002002      26     1998          None
#
#            carrera  tiene_mail
# 0      Electronica        True
# 4      Electronica        True
# 5      Electrónica        True
# 3  Info o sistemas       False
# 6  Info o sistemas        True
# 1         Mecánica        True
# 2          Química       False
